# %% [markdown]
# ## Webpage Class
#
# Define the core class which would represent every web page
#
#
# Shipped in modules/Webpage.py

# %%
test_url = {
    'amazon':'http://www.amazon.com/Cuisinart-CPT-122-Compact-2-Slice-Toaster/dp/B009GQ034C/ref=sr_1_1?s=kitchen&ie=UTF8&qid=1431620315&sr=1-1&keywords=toaster',
    'blog':'http://blog.rei.com/camp/how-to-introduce-your-indoorsy-friend-to-the-outdoors/',
    'cnn':'http://www.cnn.com/2013/06/10/politics/edward-snowden-profile/',
    'goal':"http://www.goal.com/en/news/9/england/2015/09/11/15240922/im-scared-of-van-gaals-bulldog-face-admits-rojo?ICID=HP_HN_1",
    'wiki':'https://en.wikipedia.org/wiki/Georgia_Institute_of_Technology_College_of_Computing',
    'reddit':'https://www.reddit.com/r/Barca/',
    'espn':'http://www.espnfc.us/club/atletico-madrid/1068/video/2605489/barca-look-to-continue-success-against-atleti',
    'nyt':'http://www.nytimes.com/2015/09/11/world/netanyahu-makes-quick-pivot-from-loss-on-iran-deal.html'
    
    
}

# %%
import html2text
from goose import Goose
from warnings import warn

# %%
class Webpage:
    """ The core Webpage Class 
    
    Every page which we analyze would be an instance of this class
    
    Attributes:
        url   : the url for this webpage
        text  : The cleaned text of the main article of the webpage
        title : 
        tags  : 
        meta_description:
        meta_keywords   :
        html : Complete HTML of the webpage
        __goose_article__: The inherent goose article which was used to populate these fields
    
    
    Methods:
        load(): Will load the url, and parse it to populate the data members of the object
        
        
    Not a lot of time has been spent in designing this class 
        
    """
    
    def __init__(self,url = ''):
        self.url = url
        self.text= ''
        self.title = ''
        self.tags = []
        self.meta_description = ''
        self.meta_keywords = []
        self.html = ''
        self.__goose_article__ = None
        
    def set_url(self,url):
        """ Function to set the url for this webpage"""
        # if needed check to make sure you are not over writing og url 
        self.url = url
        
    def load(self):
        """ Load, parse the URL and store its results into instance variables
        
        If goose is unable to extract the article correctly, we switch to html2text to do the same
        """
        g = Goose()
        if not self.url:
            raise ValueError('URL not set please use webpage.set_url(url) to set it')
        self.__goose_article__ = g.extract(url = self.url)
        
        self.html = self.__goose_article__.raw_html
        self.title= self.__goose_article__.title
        self.tags = self.__goose_article__.tags
        self.meta_description = self.__goose_article__.meta_description
        self.meta_keywords = self.__goose_article__.meta_keywords
        
        # Now check if goose was able to extract the main content from the url correctly or not
        if not self._valid_text_():
            # if it is not valid, we fall back to html2txt for extracting the main text
            h = html2text.HTML2Text()
            h.ignore_links = True
            self.text = h.handle(self.html.decode('utf8'))
        else:
            self.text = self.__goose_article__.cleaned_text
            
        # If you do not have anything into text now, we raise an error because we are not very sure about
        # the accuracy/performance of the parsing, so we raise a valueerror
        
        # Now this error is raised after all the required parameters in the instance are populated,
        # so even if the user chooses to do nothing with the error, it would work
        if len(self.text.strip()) == 0:
            #    raise ValueError('Unable to correctly parse given URL:%s' %self.url)

            # I guess just warning the user is enough, then it is his call to proceed with this or not
            # if we raise an error we are telling,no, yelling at him to stop
            warn('Unable to correctly parse given URL:%s' %self.url)
        
    

    
    def _valid_text_(self):
        """ Check if the text extracted by goose is valid or not base on some heuristic 
        
        Here we can have multiple definitions checking if goose works or not
        The most trivial (and quick to compute) one would be if length of the extracted text is less than 100 letters
        
        Input : 
            - webpage object
        Return : 
            - boolean
        """
        if not self.__goose_article__:
            raise ValueError("goose article not initialized, use webpage.load() to initialize it")
        
        return len(self.__goose_article__.cleaned_text) > 100

# %%
w = Webpage(test_url['espn'])

# %%
w.load()

# %%
print w.text.strip()
# Out:
# ESPN FC
#
# US Edition
#
# Scores
#
# Transfers
#
# Teams
#
# Leagues
#
# Cups
#
# Highlights
#
# More
#
# ESPN.com
#
# Search
#
# Site Terms
#
# Featured Matches
#
# Featured Matches
#
# Previous
#
# Levante
#
# Sevilla FC
#
# 6:30 PM UTC
#
# Game Details
#
# Home: 15/4  Draw: 11/4  Away: 3/4
#
# Odds from bet365
#
# bet365
#
# Borussia Monchengladbach
#
# Hamburg SV
#
# 6:30 PM UTC
#
# Game Details
#
# Home: 4/6  Draw: 3/1  Away: 4/1
#
# Odds from bet365
#
# bet365
#
# Paris Saint-Germain
#
# Bordeaux
#
# 6:30 PM UTC
#
# Game Details
#
# Home: 1/4  Draw: 19/4  Away: 12/1
#
# Odds from bet365
#
# bet365
#
# Reading
#
# Ipswich Town
#
# 7:00 PM UTC
#
# Game Details
#
# Home: 5/4  Draw: 23/10  Away: 13/5
#
# Odds from bet365
#
# bet365
#
# New York Red Bulls
#
# Chicago Fire
#
# 11:00 PM UTC
#
# Game Details
#
# Home: 8/15  Draw: 10/3  Away: 19/4
#
# Odds from bet365
#
# bet365
#
# Queretaro
#
# Morelia
#
# 12:30 AM UTC Sep 12, 2015
#
# Game Details
#
# Live football odds with bet365. Bet Now »
#
# Next
#
# ![](http://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500-dark/1068.png&
# w=126&site=espnfc)
#
#   * Atletico Madrid Home
#   * Scores &amp; Fixtures
#   * News
#   * Squad
#   * Blog
#   * Statistics
#   * Video
#   * Other Clubs
#     * Athletic Bilbao
#     * Barcelona
#     * Celta Vigo
#     * Deportivo La Coruña
#     * Eibar
#     * Espanyol
#     * Getafe
#     * Granada
#     * Las Palmas
#     * Levante
#     * Malaga
#     * Rayo Vallecano
#     * Real Betis
#     * Real Madrid
#     * Real Sociedad
#     * Sevilla FC
#     * Sporting Gijon
#     * Valencia
#     * Villarreal
#
# ## Now Playing
#
#
#
# ##  Barca look to continue success against Atleti
#
# Atletico Madrid 18 hours ago
#
# ## Related Videos
#
#
#
# ##  ESPN FC Extra Time: Barca or Atleti?
#
# Barcelona 17 hours ago
#
# Read
#
#
#
# ##  Griezmann to prove a point vs. Barca?
#
# Spanish Primera División 1 day ago
#
# Read
#
#
#
# ##  Highlights: Sevilla 0-3 Atletico Madrid
#
# Spanish Primera División Aug 30, 2015
#
# Read
#
#
#
# ##  Simeone encourages in-house competition
#
# Spanish Primera División Aug 21, 2015
#
# Read
#
#
#
# ##  Solari: Atleti must fend off Sevilla, Valencia
#
# ESPN FC TV Aug 20, 2015
#
# Read
#
#
#
# ##  Who will win La Liga this season?
#
# Spanish Primera División Aug 18, 2015
#
# Read
#
#
#
# ##  Atletico's Jackson Martinez unveiled
#
# Atletico Madrid Jul 26, 2015
#
# Read
#
#
#
# ##  ESPN FC Extra Time: Torres on the rise?
#
# ESPN FC TV Jul 20, 2015
#
# Read
#
#
#
# ##  Filipe Luis on his way back to Atleti?
#
# Transfers Jul 20, 2015
#
# Read
#
#
#
# ##  Alderweireld set for Spurs move
#
# Barclays Premier League Jul 7, 2015
#
# Read
#
#
#
# ##  Burley: Put yourself in Turan's position
#
# Spanish Primera División Jul 7, 2015
#
# Read
#
#
#
# ##  Hislop: Unsure where Turan fits with Barca
#
# ESPN FC TV Jul 6, 2015
#
# Read
#
#
#
# ##  Turan makes move to Barcelona
#
# ESPN FC TV Jul 3, 2015
#
# Read
#
#
#
# ##  Saints, Spurs to battle for Alderweireld?
#
# Barclays Premier League Jul 2, 2015
#
# Read
#
#
#
# ##  Nicol: Joining Barca worth the wait
#
# ESPN FC TV Jul 1, 2015
#
# Read
#
#
#
# ##  Marcotti: Turan may leave Atletico Madrid
#
# ESPN FC TV Jun 28, 2015
#
# Read
#
#
#
# ##  Turan done running, forcing Barca move?
#
# ESPN FC TV Jun 26, 2015
#
# Read
#
#
#
# ##  Turan seeking Premier League move
#
# Transfers Jun 24, 2015
#
# Read
#
#
#
# ##  Is Martinez an upgrade over Mandzukic?
#
# Atletico Madrid Jun 24, 2015
#
# Read
#
#
#
# ##  Marcotti: Atleti to cash in on Miranda?
#
# ESPN FC TV Jun 19, 2015
#
# Read
#
#
#
# ##  Marcotti: Mandzukic an insurance policy
#
# ESPN FC TV Jun 19, 2015
#
# Read
#
#
#
# ##  Transfer Talk: Tevez, Mandzukic and Cavani
#
# Transfers Jun 19, 2015
#
# Read
#
#
#
# ##  Consistency the key for Barca's 23rd title
#
# Spanish Primera División May 17, 2015
#
# Read
#
#
#
# ##  Kroos courting Griezmann to Bayern Munich?
#
# German Bundesliga May 6, 2015
#
# Read
#
#
#
# ##  Was Rummenigge right to criticise Atletico?
#
# ESPN FC TV Apr 23, 2015
#
# Read
#
#
#
# ##  UCL: Chicharito -- Real Madrid goal (88')
#
# UEFA Champions League Apr 22, 2015
#
# Read
#
#
#
# ##  Highlights: Real Madrid 1-0 Atletico Madrid
#
# UEFA Champions League Apr 22, 2015
#
# Read
#
#
#
# ##  Highlights: Real Madrid 1-0 Atletico Madrid
#
# UEFA Champions League Apr 22, 2015
#
# Read
#
#
#
# ##  Nicol: Atletico Madrid are slight favourites
#
# ESPN FC TV Apr 21, 2015
#
# Read
#
#
#
# ##  Salgado: Real Madrid must be patient
#
# The Boot Room Apr 21, 2015
#
# Read
#
#
ug 18, 2015\n\nRead\n\n![](...\n)\n\n##  Atletico's Jackson Martinez unveiled\n\nAtletico Madrid Jul 26, 2015\n\nRead\n\n![](...\n)\n\n##  ESPN FC Extra Time: Torres on the rise?\n\nESPN FC TV Jul 20, 2015\n\nRead\n\n![](...\n)\n\n##  Filipe Luis on his way back to Atleti?\n\nTransfers Jul 20, 2015\n\nRead\n\n![](...\n)\n\n##  Alderweireld set for Spurs move\n\nBarclays Premier League Jul 7, 2015\n\nRead\n\n![](...\n)\n\n##  Burley: Put yourself in Turan's position\n\nSpanish Primera Divisi\xf3n Jul 7, 2015\n\nRead\n\n![](...\n)\n\n##  Hislop: Unsure where Turan fits with Barca\n\nESPN FC TV Jul 6, 2015\n\nRead\n\n![](...\n)\n\n##  Turan makes move to Barcelona\n\nESPN FC TV Jul 3, 2015\n\nRead\n\n![](...\n)\n\n##  Saints, Spurs to battle for Alderweireld?\n\nBarclays Premier League Jul 2, 2015\n\nRead\n\n![](...\n)\n\n##  Nicol: Joining Barca worth the wait\n\nESPN FC TV Jul 1, 2015\n\nRead\n\n![](...\n)\n\n##  Marcotti: Turan may leave Atletico Madrid\n\nESPN FC TV Jun 28, 2015\n\nRead\n\n![](...\n)\n\n##  Turan done running, forcing Barca move?\n\nESPN FC TV Jun 26, 2015\n\nRead\n\n![](...\n)\n\n##  Turan seeking Premier League move\n\nTransfers Jun 24, 2015\n\nRead\n\n![](...\n)\n\n##  Is Martinez an upgrade over Mandzukic?\n\nAtletico Madrid Jun 24, 2015\n\nRead\n\n![](...\n)\n\n##  Marcotti: Atleti to cash in on Miranda?\n\nESPN FC TV Jun 19, 2015\n\nRead\n\n![](...\n)\n\n##  Marcotti: Mandzukic an insurance policy\n\nESPN FC TV Jun 19, 2015\n\nRead\n\n![](...\n)\n\n##  Transfer Talk: Tevez, Mandzukic and Cavani\n\nTransfers Jun 19, 2015\n\nRead\n\n![](...\n)\n\n##  Consistency the key for Barca's 23rd title\n\nSpanish Primera Divisi\xf3n May 17, 2015\n\nRead\n\n! ...

# %%
w._check_valid_text_()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-645846c2c781> in <module>()
# ----> 1 w._check_valid_text_()
#
# AttributeError: Webpage instance has no attribute '_check_valid_text_'

# %%
for site in test_url:
    w = Webpage(test_url[site])
    w.load()
    print site,w.tags
# Out:
# blog [u'Life Stages', u'Hike', u'Jennifer Davis-Flynn', u'camp', u'Tips']
# wiki []
# amazon []
# goal []
# espn []
# cnn []
# reddit []
# nyt []
# c:\anaconda\lib\site-packages\ipykernel\__main__.py:75: UserWarning: Unable to correctly parse given URL:http://www.nytimes.com/2015/09/11/world/netanyahu-makes-quick-pivot-from-loss-on-iran-deal.html

# %% [markdown]
# <span style="color:red"> Nothing seems to work for nytimes </span>
#
# Looking at the source of a page we can see that the main story exists in a ```<p>``` tag with class ="story-body-text story-content"
#
# If the work involves focus on such sites where these parsers fail, we can create new parsers using Beautiful Soup, but am skipping it for now in the interesst of time
