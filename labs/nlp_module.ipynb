# %% [markdown]
# ## nlp_module
# Here we look into the stuff we have built in the NLP module and see how to use it

# %%
import sys
sys.path.append('../modules/')

# %%
import nlp
# It is a little slow coz it has to setup the NER Tagger

# %% [markdown]
# Importing test webpages

# %%
from webpage import *

# %%
test_url['espn']
# Out:
# 'http://www.espnfc.us/club/atletico-madrid/1068/video/2605489/barca-look-to-continue-success-against-atleti'

# %%
w = Webpage(test_url['espn'])

# %%
w.load()
# Out:
# c:\anaconda\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
text = w.text

# %%
print text
# Out:
# ESPN FC
# US Edition
# Scores
# Transfers
# Teams
# Leagues
# Cups
# Highlights
# More
# ESPN.com
# Search
# Site Terms
# Featured Matches
# Featured Matches
# Previous
# Levante
# Sevilla FC
# 1
# 1
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# Borussia Monchengladbach
# Hamburg SV
# 0
# 3
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# Paris Saint-Germain
# Bordeaux
# 2
# 2
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# Reading
# Ipswich Town
# 5
# 1
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# New York Red Bulls
# Chicago Fire
# 3
# 2
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# Queretaro
# Morelia
# 0
# 1
# LIVE 28'
# Game Details
# Live football odds with bet365. Bet Now »
# Next
#
#
# Atletico Madrid Home
# Scores & Fixtures
# News
# Squad
# Blog
# Statistics
# Video
# Other Clubs
# Athletic Bilbao
# Barcelona
# Celta Vigo
# Deportivo La Coruña
# Eibar
# Espanyol
# Getafe
# ...

# %% [markdown]
# The text extracted by html2text is Markdown text, and it does a good job at getting rid of JS But adds crappy markdown
#
# Beautiful soup returns in text but is not very good with JS
#
# So
#
# ```
# html --> [html2text] --> markdown --> [markdown] --> html --> [Beautiful Soup] --> text
# ```

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(w.html)

# %%
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# %%
from markdown import markdown
html = markdown(w.text)

# %%
html_text = ''.join(BeautifulSoup(html).findAll(text=True))

# %%
print html_text
# Out:
# ESPN FC
# US Edition
# Scores
# Transfers
# Teams
# Leagues
# Cups
# Highlights
# More
# ESPN.com
# Search
# Site Terms
# Featured Matches
# Featured Matches
# Previous
# Levante
# Sevilla FC
# 1
# 1
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# Borussia Monchengladbach
# Hamburg SV
# 0
# 3
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# Paris Saint-Germain
# Bordeaux
# 2
# 2
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# Reading
# Ipswich Town
# 5
# 1
# FT
# Game Details
# Live football odds with bet365. Bet Now »
# New York Red Bulls
# Chicago Fire
# 2
# 2
# LIVE 68'
# Game Details
# Home: 1/1  Draw: 13/10  Away: 13/2
# Odds from bet365
# bet365
# Queretaro
# Morelia
# 0
# 0
# LIVE 4'
# Game Details
# Live football odds with bet365. Bet Now »
# Next
#
#
# Atletico Madrid Home
# Scores & Fixtures
# News
# Squad
# Blog
# Statistics
# Video
# Other Clubs
# Athletic Bilbao
# Barcelona
# Celta Vigo
# Deportivo La Coruña
# Eibar
# ...
