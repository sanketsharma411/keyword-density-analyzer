# %% [markdown]
# ## nlp_module
# Here we look at the nlp module and see how we can use the NER tagger

# %% [markdown]
# ### Setup

# %%
import sys
sys.path.append('../modules/')
import nlp
from webpage import *

# %%
url = test_url['wiki']
w = Webpage(url)
w.load()
text = w.text

# %% [markdown]
# ### contents of the module

# %%
print dir(nlp)
# Out:
# ['StanfordNERTagger', 'WordNetLemmatizer', '__builtins__', '__doc__', '__file__', '__name__', '__package__', 'extract_entity_names', 'java_path', 'ner_tag', 'ner_tagger_jar', 'ngram_count', 'ngrams', 'nltk', 'os', 'pos_tag', 'pre_process', 're', 'sent_chunker', 'sent_tokenize', 'sorted_ngram_count', 'st', 'stopwords', 'string', 'tagger_path', 'wnl', 'word_tokenize']

# %% [markdown]
# ## NER Tagger

# %%
print text[:500]
# Out:
# The College of Computing at the Georgia Institute of Technology has roots stretching back to an Information Science degree established in 1964.[1] In 1988, Georgia Tech president John Patrick Crecine elevated the School of Information and Computer Science to become the College of Computing, making Georgia Tech the second university to do so, after Carnegie Mellon University created their School of Computer Science.[1]
#
# Beyond using contemporary computer technology, the College of Computing also

# %%
text_ner_tags = nlp.ner_tag(text)

# %%
nlp.sorted_ngram_count(x for x in text_ner_tags if x[1] != 'O')
# Out:
# [(((u'of', u'ORGANIZATION'),), 21),
#  (((u'Georgia', u'ORGANIZATION'),), 13),
#  (((u'Tech', u'ORGANIZATION'),), 13),
#  (((u'College', u'ORGANIZATION'),), 12),
#  (((u'Computing', u'ORGANIZATION'),), 10),
#  (((u'Science', u'ORGANIZATION'),), 8),
#  (((u'School', u'ORGANIZATION'),), 8),
#  (((u'Computer', u'ORGANIZATION'),), 6),
#  (((u'Information', u'ORGANIZATION'),), 4),
#  (((u'The', u'ORGANIZATION'),), 4),
#  (((u'and', u'ORGANIZATION'),), 4),
#  (((u'Slamecka', u'PERSON'),), 3),
#  (((u'DeMillo', u'PERSON'),), 2),
#  (((u'Patrick', u'PERSON'),), 2),
#  (((u'U.S.', u'LOCATION'),), 2),
#  (((u'John', u'PERSON'),), 2),
#  (((u'University', u'ORGANIZATION'),), 2),
#  (((u"'s", u'ORGANIZATION'),), 2),
#  (((u'Miller', u'PERSON'),), 2),
#  (((u'Crecine', u'PERSON'),), 2),
#  (((u'Computational', u'ORGANIZATION'),), 2),
#  (((u'Klaus', u'PERSON'),), 2),
#  (((u'Engineering', u'ORGANIZATION'),), 2),
#  (((u'Emory', u'ORGANIZATION'),), 1),
#  (((u'Vladimir', u'PERSON'),), 1),
#  (((u'Institute', u'ORGANIZATION'),), 1),
#  (((u'Vernon', u'PERSON'),), 1),
#  (((u'Arts', u'ORGANIZATION'),), 1),
#  (((u'Technology', u'ORGANIZATION'),), 1),
#  (((u'D.', u'PERSON'),), 1),
#  (((u'Literature', u'ORGANIZATION'),), 1),
#  (((u'Media', u'ORGANIZATION'),), 1),
#  (((u'William', u'PERSON'),), 1),
#  (((u'Waldemar', u'PERSON'),), 1),
#  (((u'Freeman', u'PERSON'),), 1),
#  (((u'Barack', u'PERSON'),), 1),
#  (((u'US', u'LOCATION'),), 1),
#  (((u'CSE', u'ORGANIZATION'),), 1),
#  (((u'A.', u'PERSON'),), 1),
#  (((u'Ivan', u'ORGANIZATION'),), 1),
#  (((u'Nordiar', u'PERSON'),), 1),
#  (((u'States', u'LOCATION'),), 1),
#  (((u'Richard', u'PERSON'),), 1),
#  (((u'James', u'PERSON'),), 1),
#  (((u'SCS', u'ORGANIZATION'),), 1),
#  (((u'Interactive', u'ORGANIZATION'),), 1),
#  (((u'Atchison', u'PERSON'),), 1),
#  (((u'Chris', u'PERSON'),), 1),
#  (((u'United', u'LOCATION'),), 1),
#  (((u'Foley', u'PERSON'),), 1),
#  (((u'Gary', u'PERSON'),), 1),
#  (((u'Allen', u'ORGANIZATION'),), 1),
#  (((u'Obama', u'PERSON'),), 1),
#  (((u'Sciences', u'ORGANIZATION'),), 1),
#  (((u'Peter', u'PERSON'),), 1),
#  (((u'DARPA', u'ORGANIZATION'),), 1),
#  (((u'Mellon', u'ORGANIZATION'),), 1),
#  (((u'Crawford', u'PERSON'),), 1),
#  (((u'Ziegler', u'PERSON'),), 1),
#  (((u'Carnegie', u'ORGANIZATION'),), 1),
#  (((u'Schuster', u'PERSON'),), 1),
#  (((u'Ray', u'PERSON'),), 1),
#  (((u'IBM', u'ORGANIZATION'),), 1),
#  (((u'Zvi', u'PERSON'),), 1),
#  (((u'Liberal', u'ORGANIZATION'),), 1),
#  (((u'&', u'ORGANIZATION'),), 1),
#  (((u'Galil', u'PERSON'),), 1),
#  (((u'Dean', u'ORGANIZATION'),), 1)]

# %% [markdown]
# ## Merging NER tags
# So if two adjacent tokens have the same Tag => They are probably the same thing
#
# So the following function takes the list of (token,tag) tuples, merges the ones which are adjacent to each other and have the same tag

# %% [markdown]
# ```
# Create a new array -> merged_ner_tags
# Create an empty temp array -> temp_array
# initialize prev_tag = 'O'
# for each tag in the input array:
#     If the tag is 'O' or tag != prev_tag:
#         merge tags present in the temporary array and add it into merge_ner_Tags
#         append tag to merge_ner_tags
#         prev_tag = 'O'
#     if the tag is not 'O'
#         add it to the temporary array
#         set prev_tag
# ```

# %%
def merge_same_ner_tags(temp_array):
    """ Merge tokens from the temp array into one token_tag tuple """
    
    merged_token = ' '.join(token_tag[0] for token_tag in temp_array)
    merged_tag = tuple({token_tag[1] for token_tag in temp_array})
    if len(merged_tag) != 1:
        raise ValueError('Trying to merge tokens with different NER tags %s ' %str(temp_array))
    return merged_token,merged_tag[0]

def merge_ner_tags(text_ner_tags):
    """ Combine adjacent tokens with same NER tag into one token"""
    
    merged_ner_tags = []
    temp_array = []
    prev_tag = 'O'
    
    for token_tag in text_ner_tags:
        tag = token_tag[1]
        
        if tag == 'O':
            # There can not be an continuity so empty the array and append the results to merged
            if len(temp_array) != 0:
                # Merge the contents
                m_token,m_tag = merge_same_ner_tags(temp_array)
                merged_ner_tags.append((m_token,m_tag))
                #print temp_array,'!!!'
                temp_array = []
                
            merged_ner_tags.append(token_tag)
            prev_tag = tag
            
        elif prev_tag != 'O' and tag == prev_tag:
            # continue the chain
            temp_array.append(token_tag)
            prev_tag = tag
            
            
        else:
            # current tag != 0 and prev_tag == 0 or tag != prev_tag
            # Start of something new
            if len(temp_array) != 0:
                # Merge the contents
                m_token,m_tag = merge_same_ner_tags(temp_array)
                merged_ner_tags.append((m_token,m_tag))
                #print temp_array,'!!!'
                temp_array = []
            
            temp_array.append(token_tag)
            prev_tag = tag
            
            
    if len(temp_array) != 0:
        merged_token = ' '.join(token_tag[0] for token_tag in temp_array)
        merged_tag = tuple({token_tag[1] for token_tag in temp_array})[0]
        merged_token_tag = (merged_token,merged_tag)
        merged_ner_tags.append(merged_token_tag)
    
    return merged_ner_tags

# %%
merge_ner_tags(text_ner_tags)
# Out:
# [(u'The', u'O'),
#  (u'College', u'O'),
#  (u'of', u'O'),
#  (u'Computing', u'O'),
#  (u'at', u'O'),
#  (u'the', u'O'),
#  (u'Georgia Institute of Technology', u'ORGANIZATION'),
#  (u'has', u'O'),
#  (u'roots', u'O'),
#  (u'stretching', u'O'),
#  (u'back', u'O'),
#  (u'to', u'O'),
#  (u'an', u'O'),
#  (u'Information', u'O'),
#  (u'Science', u'O'),
#  (u'degree', u'O'),
#  (u'established', u'O'),
#  (u'in', u'O'),
#  (u'1964', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'1988', u'O'),
#  (u',', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u'president', u'O'),
#  (u'John Patrick Crecine', u'PERSON'),
#  (u'elevated', u'O'),
#  (u'the', u'O'),
#  (u'School of Information and Computer Science', u'ORGANIZATION'),
#  (u'to', u'O'),
#  (u'become', u'O'),
#  (u'the', u'O'),
#  (u'College', u'O'),
#  (u'of', u'O'),
#  (u'Computing', u'O'),
#  (u',', u'O'),
#  (u'making', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u'the', u'O'),
#  (u'second', u'O'),
#  (u'university', u'O'),
#  (u'to', u'O'),
#  (u'do', u'O'),
#  (u'so', u'O'),
#  (u',', u'O'),
#  (u'after', u'O'),
#  (u'Carnegie Mellon University', u'ORGANIZATION'),
#  (u'created', u'O'),
#  (u'their', u'O'),
#  (u'School of Computer Science', u'ORGANIZATION'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'Beyond', u'O'),
#  (u'using', u'O'),
#  (u'contemporary', u'O'),
#  (u'computer', u'O'),
#  (u'technology', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'College of Computing', u'ORGANIZATION'),
#  (u'also', u'O'),
#  (u'seeks', u'O'),
#  (u'new', u'O'),
#  (u'concepts', u'O'),
#  (u'and', u'O'),
#  (u'technology', u'O'),
#  (u',', u'O'),
#  (u'with', u'O'),
#  (u'symbiotic', u'O'),
#  (u'connections', u'O'),
#  (u'to', u'O'),
#  (u'departments', u'O'),
#  (u'in', u'O'),
#  (u'other', u'O'),
#  (u'Colleges', u'O'),
#  (u'of', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u',', u'O'),
#  (u'in', u'O'),
#  (u'a', u'O'),
#  (u'holistic', u'O'),
#  (u'manner', u'O'),
#  (u',', u'O'),
#  (u'such', u'O'),
#  (u'as', u'O'),
#  (u'combining', u'O'),
#  (u'with', u'O'),
#  (u'studies', u'O'),
#  (u'in', u'O'),
#  (u'human', u'O'),
#  (u'psychology', u'O'),
#  (u',', u'O'),
#  (u'medical', u'O'),
#  (u'science', u'O'),
#  (u',', u'O'),
#  (u'liberal', u'O'),
#  (u'arts', u'O'),
#  (u',', u'O'),
#  (u'and', u'O'),
#  (u'business', u'O'),
#  (u'(', u'O'),
#  (u'e-commerce', u'O'),
#  (u')', u'O'),
#  (u'.', u'O'),
#  (u'The', u'O'),
#  (u'most', u'O'),
#  (u'prominent', u'O'),
#  (u'example', u'O'),
#  (u'of', u'O'),
#  (u'this', u'O'),
#  (u'interdisciplinary', u'O'),
#  (u'symbosis', u'O'),
#  (u'is', u'O'),
#  (u'the', u'O'),
#  (u'College', u'O'),
#  (u"'s", u'O'),
#  (u'Threads', u'O'),
#  (u'curriculum', u'O'),
#  (u'for', u'O'),
#  (u'its', u'O'),
#  (u'B.S', u'O'),
#  (u'.', u'O'),
#  (u'in', u'O'),
#  (u'Computer', u'O'),
#  (u'Science', u'O'),
#  (u'degree', u'O'),
#  (u',', u'O'),
#  (u'launched', u'O'),
#  (u'in', u'O'),
#  (u'2006', u'O'),
#  (u'.', u'O'),
#  (u'Another', u'O'),
#  (u'example', u'O'),
#  (u'is', u'O'),
#  (u'the', u'O'),
#  (u'degree', u'O'),
#  (u'program', u'O'),
#  (u'for', u'O'),
#  (u'B.S', u'O'),
#  (u'.', u'O'),
#  (u'in', u'O'),
#  (u'Computational Media', u'ORGANIZATION'),
#  (u'is', u'O'),
#  (u'offered', u'O'),
#  (u'jointly', u'O'),
#  (u'and', u'O'),
#  (u'collaboratively', u'O'),
#  (u'within', u'O'),
#  (u"Georgia Tech 's School of Literature", u'ORGANIZATION'),
#  (u',', u'O'),
#  (u'Media', u'O'),
#  (u',', u'O'),
#  (u'and', u'O'),
#  (u'Communication', u'O'),
#  (u'in', u'O'),
#  (u'the', u'O'),
#  (u'Ivan Allen College of Liberal Arts', u'ORGANIZATION'),
#  (u'.', u'O'),
#  (u'The College of Computing', u'ORGANIZATION'),
#  (u'also', u'O'),
#  (u'has', u'O'),
#  (u'a', u'O'),
#  (u'tradition', u'O'),
#  (u'of', u'O'),
#  (u'a', u'O'),
#  (u'symbiosis', u'O'),
#  (u'between', u'O'),
#  (u'faculty', u'O'),
#  (u'and', u'O'),
#  (u'students', u'O'),
#  (u':', u'O'),
#  (u'since', u'O'),
#  (u'the', u'O'),
#  (u'early', u'O'),
#  (u'years', u'O'),
#  (u',', u'O'),
#  (u'older', u'O'),
#  (u'students', u'O'),
#  (u'have', u'O'),
#  (u'been', u'O'),
#  (u'assisting', u'O'),
#  (u'professors', u'O'),
#  (u'in', u'O'),
#  (u'research', u'O'),
#  (u'.', u'O'),
#  (u'Faculty', u'O'),
#  (u'members', u'O'),
#  (u'in', u'O'),
#  (u'the', u'O'),
#  (u'College of Computing', u'ORGANIZATION'),
#  (u'have', u'O'),
#  (u'been', u'O'),
#  (u'receptive', u'O'),
#  (u'to', u'O'),
#  (u'new', u'O'),
#  (u'technology', u'O'),
#  (u'developed', u'O'),
#  (u'with', u'O'),
#  (u'students', u'O'),
#  (u',', u'O'),
#  (u'rather', u'O'),
#  (u'than', u'O'),
#  (u'demanding', u'O'),
#  (u'outside', u'O'),
#  (u'ideas', u'O'),
#  (u'and', u'O'),
#  (u'``', u'O'),
#  (u'Not', u'O'),
#  (u'Invented', u'O'),
#  (u'Here', u'O'),
#  (u"''", u'O'),
#  (u'computer', u'O'),
#  (u'systems', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'2014', u'O'),
#  (u',', u'O'),
#  (u'U.S.', u'LOCATION'),
#  (u'News', u'O'),
#  (u'&', u'O'),
#  (u'World', u'O'),
#  (u'Report', u'O'),
#  (u'ranked', u'O'),
#  (u'the', u'O'),
#  (u'Computer', u'O'),
#  (u'Science', u'O'),
#  (u'program', u'O'),
#  (u'#', u'O'),
#  (u'9', u'O'),
#  (u'in', u'O'),
#  (u'the', u'O'),
#  (u'U.S.', u'LOCATION'),
#  (u'[', u'O'),
#  (u'6', u'O'),
#  (u']', u'O'),
#  (u'The', u'O'),
#  (u'history', u'O'),
#  (u'of', u'O'),
#  (u"Georgia Tech 's College of Computing", u'ORGANIZATION'),
#  (u'spans', u'O'),
#  (u'over', u'O'),
#  (u'43', u'O'),
#  (u'years', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'As', u'O'),
#  (u'a', u'O'),
#  (u'field', u'O'),
#  (u'of', u'O'),
#  (u'study', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'concept', u'O'),
#  (u'began', u'O'),
#  (u'in', u'O'),
#  (u'1963', u'O'),
#  (u'when', u'O'),
#  (u'a', u'O'),
#  (u'group', u'O'),
#  (u'of', u'O'),
#  (u'faculty', u'O'),
#  (u'members', u'O'),
#  (u'led', u'O'),
#  (u'by', u'O'),
#  (u'Dr.', u'O'),
#  (u'Vladimir Slamecka', u'PERSON'),
#  (u'and', u'O'),
#  (u'including', u'O'),
#  (u'Dr.', u'O'),
#  (u'Vernon Crawford', u'PERSON'),
#  (u',', u'O'),
#  (u'Dr.', u'O'),
#  (u'Nordiar Waldemar Ziegler', u'PERSON'),
#  (u',', u'O'),
#  (u'and', u'O'),
#  (u'Dr.', u'O'),
#  (u'William Atchison', u'PERSON'),
#  (u',', u'O'),
#  (u'noticed', u'O'),
#  (u'a', u'O'),
#  (u'symbiosis', u'O'),
#  (u'between', u'O'),
#  (u'departments', u'O'),
#  (u'.', u'O'),
#  (u'The', u'O'),
#  (u'group', u'O'),
#  (u'drafted', u'O'),
#  (u'an', u'O'),
#  (u'outline', u'O'),
#  (u'for', u'O'),
#  (u'a', u'O'),
#  (u'masters', u'O'),
#  (u'level', u'O'),
#  (u'program', u'O'),
#  (u'which', u'O'),
#  (u'combined', u'O'),
#  (u'library', u'O'),
#  (u'science', u'O'),
#  (u',', u'O'),
#  (u'mathematics', u'O'),
#  (u',', u'O'),
#  (u'and', u'O'),
#  (u'computer', u'O'),
#  (u'technology', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'Upon', u'O'),
#  (u'acceptance', u'O'),
#  (u'by', u'O'),
#  (u'the', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u'administration', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'M.S', u'O'),
#  (u'.', u'O'),
#  (u'in', u'O'),
#  (u'Information', u'O'),
#  (u'Science', u'O'),
#  (u'was', u'O'),
#  (u'first', u'O'),
#  (u'offered', u'O'),
#  (u'in', u'O'),
#  (u'1964', u'O'),
#  (u'under', u'O'),
#  (u'the', u'O'),
#  (u'School of Information Science', u'ORGANIZATION'),
#  (u'at', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u'led', u'O'),
#  (u'by', u'O'),
#  (u'Dr', u'O'),
#  (u'.', u'O'),
#  (u'Slamecka', u'PERSON'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'1970', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'school', u'O'),
#  (u'began', u'O'),
#  (u'offering', u'O'),
#  (u'a', u'O'),
#  (u'minor', u'O'),
#  (u'degree', u'O'),
#  (u'program', u'O'),
#  (u'for', u'O'),
#  (u'all', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u'students', u'O'),
#  (u',', u'O'),
#  (u'and', u'O'),
#  (u'was', u'O'),
#  (u'renamed', u'O'),
#  (u'to', u'O'),
#  (u'the', u'O'),
#  (u'School of Information and Computer Science', u'ORGANIZATION'),
#  (u'(', u'O'),
#  (u'ICS', u'O'),
#  (u')', u'O'),
#  (u'.', u'O'),
#  (u'Two', u'O'),
#  (u'years', u'O'),
#  (u'later', u'O'),
#  (u'in', u'O'),
#  (u'1972', u'O'),
#  (u',', u'O'),
#  (u'ICS', u'O'),
#  (u'expanded', u'O'),
#  (u'to', u'O'),
#  (u'offer', u'O'),
#  (u'an', u'O'),
#  (u'undergraduate', u'O'),
#  (u'degree', u'O'),
#  (u'for', u'O'),
#  (u'students', u'O'),
#  (u'.', u'O'),
#  (u'It', u'O'),
#  (u'also', u'O'),
#  (u'partnered', u'O'),
#  (u'with', u'O'),
#  (u'Emory University', u'ORGANIZATION'),
#  (u'to', u'O'),
#  (u'create', u'O'),
#  (u'a', u'O'),
#  (u'joint', u'O'),
#  (u'graduate', u'O'),
#  (u'program', u'O'),
#  (u'in', u'O'),
#  (u'Biomedical', u'O'),
#  (u'Information', u'O'),
#  (u'and', u'O'),
#  (u'Computer Science', u'ORGANIZATION'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'first', u'O'),
#  (u'partnership', u'O'),
#  (u'of', u'O'),
#  (u'its', u'O'),
#  (u'kind', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'1979', u'O'),
#  (u',', u'O'),
#  (u'ICS', u'O'),
#  (u"'s", u'O'),
#  (u'first', u'O'),
#  (u'director', u'O'),
#  (u'and', u'O'),
#  (u'primary', u'O'),
#  (u'founder', u'O'),
#  (u',', u'O'),
#  (u'Dr.', u'O'),
#  (u'Slamecka', u'PERSON'),
#  (u',', u'O'),
#  (u'retired', u'O'),
#  (u'from', u'O'),
#  (u'the', u'O'),
#  (u'position', u'O'),
#  (u'after', u'O'),
#  (u'15', u'O'),
#  (u'years', u'O'),
#  (u'.', u'O'),
#  (u'Dr.', u'O'),
#  (u'Ray Miller', u'PERSON'),
#  (u',', u'O'),
#  (u'IBM', u'ORGANIZATION'),
#  (u"'s", u'O'),
#  (u'Assistant', u'O'),
#  (u'Director', u'O'),
#  (u'of', u'O'),
#  (u'Mathematical', u'O'),
#  (u'Sciences', u'O'),
#  (u',', u'O'),
#  (u'was', u'O'),
#  (u'hired', u'O'),
#  (u'in', u'O'),
#  (u'his', u'O'),
#  (u'place', u'O'),
#  (u'.', u'O'),
#  (u'Under', u'O'),
#  (u'Miller', u'PERSON'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'School of Information and Computer Science', u'ORGANIZATION'),
#  (u'began', u'O'),
#  (u'a', u'O'),
#  (u'trend', u'O'),
#  (u'which', u'O'),
#  (u'began', u'O'),
#  (u'to', u'O'),
#  (u'move', u'O'),
#  (u'away', u'O'),
#  (u'from', u'O'),
#  (u'information', u'O'),
#  (u'science', u'O'),
#  (u'and', u'O'),
#  (u'towards', u'O'),
#  (u'computer', u'O'),
#  (u'science', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'John Patrick Crecine', u'PERSON'),
#  (u"'s", u'O'),
#  (u'1988', u'O'),
#  (u'reorganization', u'O'),
#  (u'of', u'O'),
#  (u'the', u'O'),
#  (u'Institute', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'School', u'O'),
#  (u'was', u'O'),
#  (u'broadened', u'O'),
#  (u'as', u'O'),
#  (u'the', u'O'),
#  (u'College of Computing', u'ORGANIZATION'),
#  (u',', u'O'),
#  (u'one', u'O'),
#  (u'of', u'O'),
#  (u'the', u'O'),
#  (u'school', u'O'),
#  (u"'s", u'O'),
#  (u'five', u'O'),
#  (u'(', u'O'),
#  (u'and', u'O'),
#  (u'in', u'O'),
#  (u'1998', u'O'),
#  (u',', u'O'),
#  (u'six', u'O'),
#  (u')', u'O'),
#  (u'colleges', u'O'),
#  (u'.', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u'was', u'O'),
#  (u'the', u'O'),
#  (u'first', u'O'),
#  (u'university', u'O'),
#  (u'in', u'O'),
#  (u'the', u'O'),
#  (u'United States', u'LOCATION'),
#  (u'to', u'O'),
#  (u'have', u'O'),
#  (u'a', u'O'),
#  (u'College', u'O'),
#  (u'of', u'O'),
#  (u'Computing', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'The', u'O'),
#  (u'school', u'O'),
#  (u'hired', u'O'),
#  (u'its', u'O'),
#  (u'first', u'O'),
#  (u'dean', u'O'),
#  (u',', u'O'),
#  (u'Peter A. Freeman', u'PERSON'),
#  (u',', u'O'),
#  (u'in', u'O'),
#  (u'1990', u'O'),
#  (u',', u'O'),
#  (u'[', u'O'),
#  (u'7', u'O'),
#  (u']', u'O'),
#  (u'and', u'O'),
#  (u'further', u'O'),
#  (u'expanded', u'O'),
#  (u'in', u'O'),
#  (u'2005', u'O'),
#  (u'with', u'O'),
#  (u'more', u'O'),
#  (u'divisions', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'1', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'2000', u'O'),
#  (u',', u'O'),
#  (u'successful', u'O'),
#  (u'internet', u'O'),
#  (u'entrepreneur', u'O'),
#  (u'and', u'O'),
#  (u'Tech', u'ORGANIZATION'),
#  (u'alum', u'O'),
#  (u'Chris Klaus', u'PERSON'),
#  (u'donated', u'O'),
#  (u'$', u'O'),
#  (u'15', u'O'),
#  (u'million', u'O'),
#  (u'towards', u'O'),
#  (u'the', u'O'),
#  (u'construction', u'O'),
#  (u'of', u'O'),
#  (u'a', u'O'),
#  (u'new', u'O'),
#  (u'building', u'O'),
#  (u'for', u'O'),
#  (u'the', u'O'),
#  (u'college', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'8', u'O'),
#  (u']', u'O'),
#  (u'[', u'O'),
#  (u'9', u'O'),
#  (u']', u'O'),
#  (u'[', u'O'),
#  (u'10', u'O'),
#  (u']', u'O'),
#  (u'At', u'O'),
#  (u'the', u'O'),
#  (u'time', u'O'),
#  (u'of', u'O'),
#  (u'Klaus', u'PERSON'),
#  (u"'", u'O'),
#  (u'contribution', u'O'),
#  (u',', u'O'),
#  (u'it', u'O'),
#  (u'was', u'O'),
#  (u'the', u'O'),
#  (u'fifth-largest', u'O'),
#  (u'contribution', u'O'),
#  (u'by', u'O'),
#  (u'an', u'O'),
#  (u'individual', u'O'),
#  (u'in', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u"'s", u'O'),
#  (u'history', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'8', u'O'),
#  (u']', u'O'),
#  (u'The', u'O'),
#  (u'building', u'O'),
#  (u'was', u'O'),
#  (u'officially', u'O'),
#  (u'opened', u'O'),
#  (u'on', u'O'),
#  (u'October', u'O'),
#  (u'26', u'O'),
#  (u',', u'O'),
#  (u'2006', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'11', u'O'),
#  (u']', u'O'),
#  (u'[', u'O'),
#  (u'12', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'February', u'O'),
#  (u'2007', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'divisions', u'O'),
#  (u'were', u'O'),
#  (u'formalized', u'O'),
#  (u'into', u'O'),
#  (u'two', u'O'),
#  (u'schools', u'O'),
#  (u':', u'O'),
#  (u'the', u'O'),
#  (u'School of Computer Science', u'ORGANIZATION'),
#  (u'(', u'O'),
#  (u'SCS', u'ORGANIZATION'),
#  (u')', u'O'),
#  (u'and', u'O'),
#  (u'the', u'O'),
#  (u'School', u'O'),
#  (u'of', u'O'),
#  (u'Interactive', u'O'),
#  (u'Computing', u'O'),
#  (u'(', u'O'),
#  (u'SIC', u'O'),
#  (u')', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'13', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'June', u'O'),
#  (u'2008', u'O'),
#  (u',', u'O'),
#  (u'College of Computing Dean', u'ORGANIZATION'),
#  (u'Richard DeMillo', u'PERSON'),
#  (u'announced', u'O'),
#  (u'plans', u'O'),
#  (u'for', u'O'),
#  (u'his', u'O'),
#  (u'resignation', u'O'),
#  (u',', u'O'),
#  (u'citing', u'O'),
#  (u'conflicts', u'O'),
#  (u'with', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u'provost', u'O'),
#  (u'and', u'O'),
#  (u'interim', u'O'),
#  (u'president', u'O'),
#  (u'Gary Schuster', u'PERSON'),
#  (u'.', u'O'),
#  (u'DeMillo', u'PERSON'),
#  (u'was', u'O'),
#  (u'temporarily', u'O'),
#  (u'replaced', u'O'),
#  (u'by', u'O'),
#  (u'James D. Foley', u'PERSON'),
#  (u',', u'O'),
#  (u'a', u'O'),
#  (u'professor', u'O'),
#  (u'in', u'O'),
#  (u'the', u'O'),
#  (u'School of Interactive Computing', u'ORGANIZATION'),
#  (u',', u'O'),
#  (u'until', u'O'),
#  (u'a', u'O'),
#  (u'permanent', u'O'),
#  (u'replacement', u'O'),
#  (u'could', u'O'),
#  (u'be', u'O'),
#  (u'found', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'14', u'O'),
#  (u']', u'O'),
#  (u'On', u'O'),
#  (u'April', u'O'),
#  (u'9', u'O'),
#  (u',', u'O'),
#  (u'2010', u'O'),
#  (u',', u'O'),
#  (u'Zvi Galil', u'PERSON'),
#  (u'was', u'O'),
#  (u'named', u'O'),
#  (u'the', u'O'),
#  (u'college', u'O'),
#  (u"'s", u'O'),
#  (u'new', u'O'),
#  (u'dean', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'2', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'March', u'O'),
#  (u'2010', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'division', u'O'),
#  (u'of', u'O'),
#  (u'Computational Science & Engineering', u'ORGANIZATION'),
#  (u'(', u'O'),
#  (u'CSE', u'ORGANIZATION'),
#  (u')', u'O'),
#  (u'was', u'O'),
#  (u'also', u'O'),
#  (u'formalized', u'O'),
#  (u'into', u'O'),
#  (u'a', u'O'),
#  (u'school', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'15', u'O'),
#  (u']', u'O'),
#  (u'The', u'O'),
#  (u'school', u'O'),
#  (u'is', u'O'),
#  (u'involved', u'O'),
#  (u'in', u'O'),
#  (u'DARPA', u'ORGANIZATION'),
#  (u"'s", u'O'),
#  (u'ADAMS', u'O'),
#  (u'project', u'O'),
#  (u'via', u'O'),
#  (u'the', u'O'),
#  (u'Proactive', u'O'),
#  (u'Discovery', u'O'),
#  (u'of', u'O'),
#  (u'Insider', u'O'),
#  (u'Threats', u'O'),
#  (u'Using', u'O'),
#  (u'Graph', u'O'),
#  (u'Analysis', u'O'),
#  (u'and', u'O'),
#  (u'Learning', u'O'),
#  (u'system', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'16', u'O'),
#  (u']', u'O'),
#  (u'[', u'O'),
#  (u'17', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'May', u'O'),
#  (u'2013', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'school', u'O'),
#  (u'announced', u'O'),
#  (u'that', u'O'),
#  (u'it', u'O'),
#  (u'will', u'O'),
#  (u'offer', u'O'),
#  (u'the', u'O'),
#  (u'first', u'O'),
#  (u'professional', u'O'),
#  (u'Online', u'O'),
#  (u'Master', u'O'),
#  (u'of', u'O'),
#  (u'Science', u'O'),
#  (u'degree', u'O'),
#  (u'in', u'O'),
#  (u'computer', u'O'),
#  (u'science', u'O'),
#  (u'(', u'O'),
#  (u'OMS', u'O'),
#  (u'CS', u'O'),
#  (u')', u'O'),
#  (u'that', u'O'),
#  (u'can', u'O'),
#  (u'be', u'O'),
#  (u'earned', u'O'),
#  (u'completely', u'O'),
#  (u'through', u'O'),
#  (u'the', u'O'),
#  (u'massive', u'O'),
#  (u'online', u'O'),
#  (u'(', u'O'),
#  (u'MOOC', u'O'),
#  (u')', u'O'),
#  (u'format', u'O'),
#  (u'in', u'O'),
#  (u'partnership', u'O'),
#  (u'with', u'O'),
#  (u'Udacity', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'18', u'O'),
#  (u']', u'O'),
#  (u'In', u'O'),
#  (u'August', u'O'),
#  (u'2013', u'O'),
#  (u',', u'O'),
#  (u'US', u'LOCATION'),
#  (u'President', u'O'),
#  (u'Barack Obama', u'PERSON'),
#  (u'praised', u'O'),
#  (u'the', u'O'),
#  (u'school', u'O'),
#  (u'as', u'O'),
#  (u'a', u'O'),
#  (u'national', u'O'),
#  (u'leader', u'O'),
#  (u'in', u'O'),
#  (u'computer', u'O'),
#  (u'science', u'O'),
#  (u'that', u'O'),
#  (u'is', u'O'),
#  (u'offering', u'O'),
#  (u'a', u'O'),
#  (u'master', u'O'),
#  (u"'s", u'O'),
#  (u'degree', u'O'),
#  (u'in', u'O'),
#  (u'computer', u'O'),
#  (u'science', u'O'),
#  (u'at', u'O'),
#  (u'a', u'O'),
#  (u'fraction', u'O'),
#  (u'of', u'O'),
#  (u'the', u'O'),
#  (u'cost', u'O'),
#  (u"''", u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'19', u'O'),
#  (u']', u'O'),
#  (u'The College of Computing', u'ORGANIZATION'),
#  (u'has', u'O'),
#  (u'evolved', u'O'),
#  (u',', u'O'),
#  (u'along', u'O'),
#  (u'with', u'O'),
#  (u'advancing', u'O'),
#  (u'computing', u'O'),
#  (u'technology', u'O'),
#  (u'and', u'O'),
#  (u'applications', u'O'),
#  (u',', u'O'),
#  (u'to', u'O'),
#  (u'offer', u'O'),
#  (u'an', u'O'),
#  (u'increasing', u'O'),
#  (u'variety', u'O'),
#  (u'of', u'O'),
#  (u'specialized', u'O'),
#  (u'degrees', u'O'),
#  (u',', u'O'),
#  (u'including', u'O'),
#  (u':', u'O'),
#  (u'The', u'O'),
#  (u'following', u'O'),
#  (u'graduate', u'O'),
#  (u'certificates', u'O'),
#  (u'are', u'O'),
#  (u'offered', u'O'),
#  (u':', u'O'),
#  (u'Additionally', u'O'),
#  (u',', u'O'),
#  (u'the', u'O'),
#  (u'following', u'O'),
#  (u'degrees', u'O'),
#  (u'are', u'O'),
#  (u'offered', u'O'),
#  (u':', u'O'),
#  (u'The College of Computing', u'ORGANIZATION'),
#  (u'is', u'O'),
#  (u'the', u'O'),
#  (u'third-highest', u'O'),
#  (u'of', u'O'),
#  (u'Georgia Tech', u'ORGANIZATION'),
#  (u"'s", u'O'),
#  (u'six', u'O'),
#  (u'colleges', u'O'),
#  (u'(', u'O'),
#  (u'behind', u'O'),
#  (u'the', u'O'),
#  (u'larger', u'O'),
#  (u'and', u'O'),
#  (u'older', u'O'),
#  (u'College of Engineering and College of Sciences', u'ORGANIZATION'),
#  (u')', u'O'),
#  (u'in', u'O'),
#  (u'research', u'O'),
#  (u'awards', u'O'),
#  (u',', u'O'),
#  (u'with', u'O'),
#  (u'139', u'O'),
#  (u'proposals', u'O'),
#  (u'worth', u'O'),
#  (u'$', u'O'),
#  (u'93,737,529', u'O'),
#  (u'resulting', u'O'),
#  (u'in', u'O'),
#  (u'119', u'O'),
#  (u'awards', u'O'),
#  (u'worth', u'O'),
#  (u'$', u'O'),
#  (u'14,579,392', u'O'),
#  (u'in', u'O'),
#  (u'2006', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'23', u'O'),
#  (u']', u'O'),
#  (u'There', u'O'),
#  (u'are', u'O'),
#  (u'several', u'O'),
#  (u'organizations', u'O'),
#  (u'tied', u'O'),
#  (u'to', u'O'),
#  (u'or', u'O'),
#  (u'within', u'O'),
#  (u'the', u'O'),
#  (u'College', u'O'),
#  (u'of', u'O'),
#  (u'Computing', u'O'),
#  (u'that', u'O'),
#  (u'are', u'O'),
#  (u'primarily', u'O'),
#  (u'dedicated', u'O'),
#  (u'to', u'O'),
#  (u'research', u'O'),
#  (u'.', u'O'),
#  (u'These', u'O'),
#  (u'include', u'O'),
#  (u'several', u'O'),
#  (u'research', u'O'),
#  (u'groups', u'O'),
#  (u'and', u'O'),
#  (u'labs', u'O'),
#  (u'.', u'O'),
#  (u'[', u'O'),
#  (u'24', u'O'),
#  (u']', u'O'),
#  (u'Other', u'O'),
#  (u'research-related', u'O'),
#  (u'organizations', u'O'),
#  (u'include', u'O'),
#  (u':', u'O'),
#  (u'The College of Computing', u'ORGANIZATION'),
#  (u'has', u'O'),
#  (u'numerous', u'O'),
#  (u'student', u'O'),
#  (u'organizations', u'O'),
#  (u'which', u'O'),
#  (u'help', u'O'),
#  (u'build', u'O'),
#  (u'a', u'O'),
#  (u'community', u'O'),
#  (u'within', u'O'),
#  (u'the', u'O'),
#  (u'college', u'O'),
#  (u'.', u'O'),
#  (u'These', u'O'),
#  (u'organizations', u'O'),
#  (u'include', u'O'),
#  (u':', u'O')]

# %%
tagged_entities = [tag for tag in merge_ner_tags(text_ner_tags) if tag[1] != 'O']

# %%
# Merge similar tokens
tag_collected = {tag:[x[0] for x in tagged_entities if x[1] == tag] for tag in {x[1] for x in tagged_entities}}
# Dict with keys as tags and values as all the entities with that tag
tag_collected
# Out:
# {u'LOCATION': [u'U.S.', u'U.S.', u'United States', u'US'],
#  u'ORGANIZATION': [u'Georgia Institute of Technology',
#   u'Georgia Tech',
#   u'School of Information and Computer Science',
#   u'Georgia Tech',
#   u'Carnegie Mellon University',
#   u'School of Computer Science',
#   u'College of Computing',
#   u'Georgia Tech',
#   u'Computational Media',
#   u"Georgia Tech 's School of Literature",
#   u'Ivan Allen College of Liberal Arts',
#   u'The College of Computing',
#   u'College of Computing',
#   u"Georgia Tech 's College of Computing",
#   u'Georgia Tech',
#   u'School of Information Science',
#   u'Georgia Tech',
#   u'Georgia Tech',
#   u'School of Information and Computer Science',
#   u'Emory University',
#   u'Computer Science',
#   u'IBM',
#   u'School of Information and Computer Science',
#   u'College of Computing',
#   u'Georgia Tech',
#   u'Tech',
#   u'Georgia Tech',
#   u'School of Computer Science',
#   u'SCS',
#   u'College of Computing Dean',
#   u'Georgia Tech',
#   u'School of Interactive Computing',
#   u'Computational Science & Engineering',
#   u'CSE',
#   u'DARPA',
#   u'The College of Computing',
#   u'The College of Computing',
#   u'Georgia Tech',
#   u'College of Engineering and College of Sciences',
#   u'The College of Computing'],
#  u'PERSON': [u'John Patrick Crecine',
#   u'Vladimir Slamecka',
#   u'Vernon Crawford',
#   u'Nordiar Waldemar Ziegler',
#   u'William Atchison',
#   u'Slamecka',
#   u'Slamecka',
#   u'Ray Miller',
#   u'Miller',
#   u'John Patrick Crecine',
#   u'Peter A. Freeman',
#   u'Chris Klaus',
#   u'Klaus',
#   u'Richard DeMillo',
#   u'Gary Schuster',
#   u'DeMillo',
#   u'James D. Foley',
#   u'Zvi Galil',
#   u'Barack Obama']}

# %%
# For every token see if it is a part of any other token if yes replace it by the bigger token
tag = 'PERSON'
def reduce_tag_tokens(tokens):
    """ Look at the tokens with the same NER tag and merge them if they are 'similar'
    
    Current definitions of similarity
        Compare the tag with every other tag and if the first tag is a part of a bigger tag
        Then they are probably referring to the same thing, so replace the smaller one by the bigger one
        
    input : list of tokens which have the same NER tag
    Output: list of reduced tokens
    
    TODO : Add Abbreviation to similarity thing
    
    """
    new_tags = []
    for token in tokens:
        flag = 0 
        for other_token in sorted(tokens,key = lambda x:len(x), reverse = True):
            if compare_tokens(token,other_token):
                new_tags.append(other_token)
                flag = 1
                break
        if flag != 1:
            new_tags.append(token)

    return new_tags

def compare_tokens(token,other_token):
    """ Compare two tokens to see if they are similar or not"""
    return ((token in other_token
                    and len(other_token) > len(token)
                    and "'s" not in other_token
                    and "of" not in other_token)
                or ("The" in other_token 
                    and token in other_token.replace("The",' ')
                   )
                or (token in get_abbr(other_token))
           )

# %% [markdown]
# "'s" and "of" create problems when "Gerogia Tech 's School of Literature"  merges with "Georgia Tech" => Avoid them
# But avoiding them creates another problem:
# "College of Computing"
#
# Still something is getting fucked up here

# %%
def get_abbr(st):
    """ Generate an abbreviation of the passed string by some rule and return it 
    
    
    input : string 
    output: set of possible abbreviations
    
    Current method of abbr:
        Pick up first leter of every word
        Capitalize it
            1. One abbr would have it as U.S.
            2. Another abbr would be as US
    
    Thus you cannot abbreviate single word strings
    
    TODO : Use some library to do this
    """
    words = st.replace('The','').replace('of','').replace('&','').split()
    if len(words) < 2:
        return {}
    
    first_letters = [word[0].capitalize() for word in words]
    
    abbr_1 = '.'.join(first_letters)+'.'
    abbr_2 = ''.join(first_letters)
    
    return {abbr_1,abbr_2}
get_abbr('National Securoty Agency')
# Out:
# {'N.S.A.', 'NSA'}

# %%
for tag in tag_collected:
    print reduce_tag_tokens(tag_collected[tag])
# Out:
# [u'Georgia Institute of Technology', u"Georgia Tech 's School of Literature", u'School of Information and Computer Science', u"Georgia Tech 's School of Literature", u'Carnegie Mellon University', u'School of Computer Science', u"Georgia Tech 's College of Computing", u"Georgia Tech 's School of Literature", u'Computational Media', u"Georgia Tech 's School of Literature", u'Ivan Allen College of Liberal Arts', u'The College of Computing', u"Georgia Tech 's College of Computing", u"Georgia Tech 's College of Computing", u"Georgia Tech 's School of Literature", u'School of Information Science', u"Georgia Tech 's School of Literature", u"Georgia Tech 's School of Literature", u'School of Information and Computer Science', u'Emory University', u'School of Information and Computer Science', u'IBM', u'School of Information and Computer Science', u"Georgia Tech 's College of Computing", u"Georgia Tech 's School of Literature", u"Georgia Tech 's School of Literature", u"Georgia Tech 's School of Literature", u'School of Computer Science', u'School of Computer Science', u'College of Computing Dean', u"Georgia Tech 's School of Literature", u'School of Interactive Computing', u'Computational Science & Engineering', u'Computational Science & Engineering', u'DARPA', u'The College of Computing', u'The College of Computing', u"Georgia Tech 's School of Literature", u'College of Engineering and College of Sciences', u'The College of Computing']
# [u'United States', u'United States', u'United States', u'United States']
# [u'John Patrick Crecine', u'Vladimir Slamecka', u'Vernon Crawford', u'Nordiar Waldemar Ziegler', u'William Atchison', u'Vladimir Slamecka', u'Vladimir Slamecka', u'Ray Miller', u'Ray Miller', u'John Patrick Crecine', u'Peter A. Freeman', u'Chris Klaus', u'Chris Klaus', u'Richard DeMillo', u'Gary Schuster', u'Richard DeMillo', u'James D. Foley', u'Zvi Galil', u'Barack Obama']

# %%
for tag in tag_collected:
    print nlp.sorted_ngram_count(reduce_tag_tokens(tag_collected[tag]))
# Out:
# [((u'Georgia Tech',), 11), ((u'The College of Computing',), 7), ((u'School of Computer Science',), 3), ((u'School of Information and Computer Science',), 3), ((u'Computational Science & Engineering',), 2), ((u"Georgia Tech 's School of Literature",), 1), ((u'Computer Science',), 1), ((u"Georgia Tech 's College of Computing",), 1), ((u'Georgia Institute of Technology',), 1), ((u'College of Engineering and College of Sciences',), 1), ((u'Ivan Allen College of Liberal Arts',), 1), ((u'IBM',), 1), ((u'DARPA',), 1), ((u'College of Computing Dean',), 1), ((u'School of Interactive Computing',), 1), ((u'Carnegie Mellon University',), 1), ((u'Emory University',), 1), ((u'Computational Media',), 1), ((u'School of Information Science',), 1)]
# [((u'United States',), 4)]
# [((u'Vladimir Slamecka',), 3), ((u'Chris Klaus',), 2), ((u'Richard DeMillo',), 2), ((u'Ray Miller',), 2), ((u'John Patrick Crecine',), 2), ((u'Vernon Crawford',), 1), ((u'Zvi Galil',), 1), ((u'Peter A. Freeman',), 1), ((u'William Atchison',), 1), ((u'Gary Schuster',), 1), ((u'James D. Foley',), 1), ((u'Nordiar Waldemar Ziegler',), 1), ((u'Barack Obama',), 1)]

# %%
url
# Out:
# 'https://en.wikipedia.org/wiki/Georgia_Institute_of_Technology_College_of_Computing'
